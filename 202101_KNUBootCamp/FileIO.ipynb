# %% [markdown]
# <a href="https://colab.research.google.com/github/parkrye/Python/blob/main/202101_KNUBootCamp/FileIO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#info.txt 만들기
import random
alphabet = list('가나다라마바사아자차카타파하')

with open('info.txt', 'w') as file:
  for i in range(1000):
    name = random.choice(alphabet) + random.choice(alphabet)
    weight = random.randrange(40, 100)
    height = random.randrange(140, 200)
    file.write('{}, {}, {}\n'.format(name, weight, height))

#고객데이터파일을 읽고 bmi계산 출력
with open('info.txt', 'r') as file:
  for line in file:
    (name, weight, height) = line.strip().split(', ')

    if (not name) or (not weight) or (not height): continue
    else:
      bmi = int(int(weight) / (int(height) * int(height)) * 10000)
      result = ''
      if bmi < 18.5:
        result = '저체중'
      elif bmi < 23:
        result = '정상체중'
      elif bmi < 25:
        result = '과체중'
      else:
        result = '비만'

      print('이름 : {}'.format(name))
      print('체중 : {}'.format(weight))
      print('신장 : {}'.format(height))
      print('BMI : {}'.format(bmi))
      print('결과 : {}\n'.format(result))
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# 결과 : 과체중
#
# 이름 : 타카
# 체중 : 52
# 신장 : 142
# BMI : 25
# 결과 : 비만
#
# 이름 : 차라
# 체중 : 67
# 신장 : 199
# BMI : 16
# 결과 : 저체중
#
# 이름 : 자다
# 체중 : 70
# 신장 : 166
# BMI : 25
# 결과 : 비만
#
# 이름 : 자나
# 체중 : 67
# 신장 : 158
# BMI : 26
# 결과 : 비만
#
# 이름 : 다자
# 체중 : 96
# 신장 : 168
# BMI : 34
# 결과 : 비만
#
# 이름 : 마차
# 체중 : 65
# 신장 : 142
# BMI : 32
# 결과 : 비만
#
# 이름 : 사사
# 체중 : 55
# 신장 : 168
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 타아
# 체중 : 55
# 신장 : 166
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 하가
# 체중 : 71
# 신장 : 157
# BMI : 28
# 결과 : 비만
#
# 이름 : 바나
# 체중 : 43
# 신장 : 181
# BMI : 13
# 결과 : 저체중
#
# 이름 : 자바
# 체중 : 84
# 신장 : 173
# BMI : 28
# 결과 : 비만
#
# 이름 : 라파
# 체중 : 49
# 신장 : 172
# BMI : 16
# 결과 : 저체중
#
# 이름 : 사아
# 체중 : 96
# 신장 : 176
# BMI : 30
# 결과 : 비만
#
# 이름 : 파가
# 체중 : 41
# 신장 : 185
# BMI : 11
# 결과 : 저체중
#
# 이름 : 아바
# 체중 : 84
# 신장 : 156
# BMI : 34
# 결과 : 비만
#
# 이름 : 나자
# 체중 : 77
# 신장 : 196
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 다카
# 체중 : 98
# 신장 : 181
# BMI : 29
# 결과 : 비만
#
# 이름 : 가타
# 체중 : 77
# 신장 : 167
# BMI : 27
# 결과 : 비만
#
# 이름 : 바바
# 체중 : 46
# 신장 : 147
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 라아
# 체중 : 54
# 신장 : 180
# BMI : 16
# 결과 : 저체중
#
# 이름 : 자라
# 체중 : 99
# 신장 : 158
# BMI : 39
# 결과 : 비만
#
# 이름 : 카다
# 체중 : 85
# 신장 : 141
# BMI : 42
# 결과 : 비만
#
# 이름 : 하사
# 체중 : 70
# 신장 : 196
# BMI : 18
# 결과 : 저체중
#
# 이름 : 차나
# 체중 : 68
# 신장 : 178
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 사가
# 체중 : 46
# 신장 : 198
# BMI : 11
# 결과 : 저체중
#
# 이름 : 카자
# 체중 : 59
# 신장 : 160
# BMI : 23
# 결과 : 과체중
#
# 이름 : 하파
# 체중 : 79
# 신장 : 173
# BMI : 26
# 결과 : 비만
#
# 이름 : 마카
# 체중 : 51
# 신장 : 164
# BMI : 18
# 결과 : 저체중
#
# 이름 : 카나
# 체중 : 47
# 신장 : 177
# BMI : 15
# 결과 : 저체중
#
# 이름 : 바라
# 체중 : 74
# 신장 : 164
# BMI : 27
# 결과 : 비만
#
# 이름 : 차나
# 체중 : 58
# 신장 : 162
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 나마
# 체중 : 82
# 신장 : 195
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 파사
# 체중 : 55
# 신장 : 193
# BMI : 14
# 결과 : 저체중
#
# 이름 : 가가
# 체중 : 88
# 신장 : 184
# BMI : 25
# 결과 : 비만
#
# 이름 : 파다
# 체중 : 54
# 신장 : 193
# BMI : 14
# 결과 : 저체중
#
# 이름 : 가카
# 체중 : 45
# 신장 : 141
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 아사
# 체중 : 98
# 신장 : 140
# BMI : 50
# 결과 : 비만
#
# 이름 : 가라
# 체중 : 57
# 신장 : 165
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 사자
# 체중 : 90
# 신장 : 175
# BMI : 29
# 결과 : 비만
#
# 이름 : 라파
# 체중 : 48
# 신장 : 191
# BMI : 13
# 결과 : 저체중
#
# 이름 : 바마
# 체중 : 99
# 신장 : 196
# BMI : 25
# 결과 : 비만
#
# 이름 : 자가
# 체중 : 88
# 신장 : 158
# BMI : 35
# 결과 : 비만
#
# 이름 : 파가
# 체중 : 79
# 신장 : 149
# BMI : 35
# 결과 : 비만
#
# 이름 : 나타
# 체중 : 87
# 신장 : 182
# BMI : 26
# 결과 : 비만
#
# 이름 : 타타
# 체중 : 53
# 신장 : 193
# BMI : 14
# 결과 : 저체중
#
# 이름 : 바마
# 체중 : 55
# 신장 : 151
# BMI : 24
# 결과 : 과체중
#
# 이름 : 카카
# 체중 : 82
# 신장 : 188
# BMI : 23
# 결과 : 과체중
#
# 이름 : 아아
# 체중 : 55
# 신장 : 144
# BMI : 26
# 결과 : 비만
#
# 이름 : 라마
# 체중 : 48
# 신장 : 162
# BMI : 18
# 결과 : 저체중
#
# 이름 : 차차
# 체중 : 84
# 신장 : 178
# BMI : 26
# 결과 : 비만
#
# 이름 : 차아
# 체중 : 95
# 신장 : 198
# BMI : 24
# 결과 : 과체중
#
# 이름 : 차라
# 체중 : 61
# 신장 : 180
# BMI : 18
# 결과 : 저체중
#
# 이름 : 파나
# 체중 : 61
# 신장 : 175
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 차다
# 체중 : 94
# 신장 : 185
# BMI : 27
# 결과 : 비만
#
# 이름 : 마바
# 체중 : 86
# 신장 : 154
# BMI : 36
# 결과 : 비만
#
# 이름 : 사하
# 체중 : 48
# 신장 : 183
# BMI : 14
# 결과 : 저체중
#
# 이름 : 하자
# 체중 : 87
# 신장 : 165
# BMI : 31
# 결과 : 비만
#
# 이름 : 마가
# 체중 : 77
# 신장 : 140
# BMI : 39
# 결과 : 비만
#
# 이름 : 파타
# 체중 : 66
# 신장 : 166
# BMI : 23
# 결과 : 과체중
#
# 이름 : 마사
# 체중 : 56
# 신장 : 162
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 파아
# 체중 : 40
# 신장 : 170
# BMI : 13
# 결과 : 저체중
#
# 이름 : 다타
# 체중 : 83
# 신장 : 184
# BMI : 24
# 결과 : 과체중
#
# 이름 : 바바
# 체중 : 70
# 신장 : 195
# BMI : 18
# 결과 : 저체중
#
# 이름 : 라나
# 체중 : 87
# 신장 : 158
# BMI : 34
# 결과 : 비만
#
# 이름 : 마카
# 체중 : 60
# 신장 : 143
# BMI : 29
# 결과 : 비만
#
# 이름 : 바다
# 체중 : 94
# 신장 : 177
# BMI : 30
# 결과 : 비만
#
# 이름 : 아사
# 체중 : 56
# 신장 : 177
# BMI : 17
# 결과 : 저체중
#
# 이름 : 바가
# 체중 : 79
# 신장 : 193
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 라사
# 체중 : 55
# 신장 : 173
# BMI : 18
# 결과 : 저체중
#
# 이름 : 아나
# 체중 : 67
# 신장 : 182
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 카사
# 체중 : 64
# 신장 : 169
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 나하
# 체중 : 40
# 신장 : 150
# BMI : 17
# 결과 : 저체중
#
# 이름 : 라타
# 체중 : 44
# 신장 : 166
# BMI : 15
# 결과 : 저체중
#
# 이름 : 나마
# 체중 : 42
# 신장 : 158
# BMI : 16
# 결과 : 저체중
#
# 이름 : 마자
# 체중 : 82
# 신장 : 146
# BMI : 38
# 결과 : 비만
#
# 이름 : 하다
# 체중 : 66
# 신장 : 173
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 바라
# 체중 : 79
# 신장 : 198
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 카사
# 체중 : 48
# 신장 : 164
# BMI : 17
# 결과 : 저체중
#
# 이름 : 나다
# 체중 : 61
# 신장 : 164
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 다차
# 체중 : 99
# 신장 : 170
# BMI : 34
# 결과 : 비만
#
# 이름 : 타차
# 체중 : 72
# 신장 : 160
# BMI : 28
# 결과 : 비만
#
# 이름 : 차라
# 체중 : 53
# 신장 : 188
# BMI : 14
# 결과 : 저체중
#
# 이름 : 마가
# 체중 : 97
# 신장 : 155
# BMI : 40
# 결과 : 비만
#
# 이름 : 나다
# 체중 : 80
# 신장 : 197
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 카하
# 체중 : 75
# 신장 : 187
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 사라
# 체중 : 41
# 신장 : 160
# BMI : 16
# 결과 : 저체중
#
# 이름 : 자마
# 체중 : 92
# 신장 : 146
# BMI : 43
# 결과 : 비만
#
# 이름 : 타하
# 체중 : 85
# 신장 : 147
# BMI : 39
# 결과 : 비만
#
# 이름 : 바아
# 체중 : 55
# 신장 : 150
# BMI : 24
# 결과 : 과체중
#
# 이름 : 다카
# 체중 : 53
# 신장 : 186
# BMI : 15
# 결과 : 저체중
#
# 이름 : 자파
# 체중 : 71
# 신장 : 167
# BMI : 25
# 결과 : 비만
#
# 이름 : 자파
# 체중 : 79
# 신장 : 157
# BMI : 32
# 결과 : 비만
#
# 이름 : 나아
# 체중 : 49
# 신장 : 140
# BMI : 25
# 결과 : 비만
#
# 이름 : 차아
# 체중 : 40
# 신장 : 173
# BMI : 13
# 결과 : 저체중
#
# 이름 : 사하
# 체중 : 62
# 신장 : 177
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 바가
# 체중 : 60
# 신장 : 193
# BMI : 16
# 결과 : 저체중
#
# 이름 : 아사
# 체중 : 52
# 신장 : 194
# BMI : 13
# 결과 : 저체중
#
# 이름 : 차자
# 체중 : 82
# 신장 : 153
# BMI : 35
# 결과 : 비만
#
# 이름 : 자파
# 체중 : 54
# 신장 : 173
# BMI : 18
# 결과 : 저체중
#
# 이름 : 아사
# 체중 : 85
# 신장 : 196
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 나하
# 체중 : 65
# 신장 : 155
# BMI : 27
# 결과 : 비만
#
# 이름 : 라사
# 체중 : 45
# 신장 : 142
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 카사
# 체중 : 77
# 신장 : 170
# BMI : 26
# 결과 : 비만
#
# 이름 : 하사
# 체중 : 57
# 신장 : 151
# BMI : 24
# 결과 : 과체중
#
# 이름 : 사하
# 체중 : 61
# 신장 : 171
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 카차
# 체중 : 58
# 신장 : 160
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 라아
# 체중 : 49
# 신장 : 197
# BMI : 12
# 결과 : 저체중
#
# 이름 : 라나
# 체중 : 90
# 신장 : 169
# BMI : 31
# 결과 : 비만
#
# 이름 : 다다
# 체중 : 82
# 신장 : 196
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 다타
# 체중 : 44
# 신장 : 161
# BMI : 16
# 결과 : 저체중
#
# 이름 : 카나
# 체중 : 86
# 신장 : 195
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 사차
# 체중 : 53
# 신장 : 182
# BMI : 16
# 결과 : 저체중
#
# 이름 : 바나
# 체중 : 66
# 신장 : 191
# BMI : 18
# 결과 : 저체중
#
# 이름 : 마다
# 체중 : 98
# 신장 : 145
# BMI : 46
# 결과 : 비만
#
# 이름 : 다차
# 체중 : 42
# 신장 : 196
# BMI : 10
# 결과 : 저체중
#
# 이름 : 마차
# 체중 : 47
# 신장 : 170
# BMI : 16
# 결과 : 저체중
#
# 이름 : 사하
# 체중 : 75
# 신장 : 188
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 가사
# 체중 : 69
# 신장 : 165
# BMI : 25
# 결과 : 비만
#
# 이름 : 나차
# 체중 : 55
# 신장 : 172
# BMI : 18
# 결과 : 저체중
#
# 이름 : 다자
# 체중 : 92
# 신장 : 193
# BMI : 24
# 결과 : 과체중
#
# 이름 : 하자
# 체중 : 55
# 신장 : 197
# BMI : 14
# 결과 : 저체중
#
# 이름 : 사가
# 체중 : 65
# 신장 : 195
# BMI : 17
# 결과 : 저체중
#
# 이름 : 사사
# 체중 : 99
# 신장 : 199
# BMI : 24
# 결과 : 과체중
#
# 이름 : 타마
# 체중 : 84
# 신장 : 160
# BMI : 32
# 결과 : 비만
#
# 이름 : 다자
# 체중 : 67
# 신장 : 188
# BMI : 18
# 결과 : 저체중
#
# 이름 : 카자
# 체중 : 56
# 신장 : 193
# BMI : 15
# 결과 : 저체중
#
# 이름 : 바바
# 체중 : 55
# 신장 : 194
# BMI : 14
# 결과 : 저체중
#
# 이름 : 마파
# 체중 : 62
# 신장 : 176
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 다라
# 체중 : 84
# 신장 : 147
# BMI : 38
# 결과 : 비만
#
# 이름 : 사파
# 체중 : 63
# 신장 : 145
# BMI : 29
# 결과 : 비만
#
# 이름 : 사라
# 체중 : 81
# 신장 : 147
# BMI : 37
# 결과 : 비만
#
# 이름 : 라하
# 체중 : 62
# 신장 : 145
# BMI : 29
# 결과 : 비만
#
# 이름 : 타파
# 체중 : 90
# 신장 : 186
# BMI : 26
# 결과 : 비만
#
# 이름 : 타바
# 체중 : 70
# 신장 : 143
# BMI : 34
# 결과 : 비만
#
# 이름 : 자아
# 체중 : 87
# 신장 : 165
# BMI : 31
# 결과 : 비만
#
# 이름 : 마카
# 체중 : 61
# 신장 : 143
# BMI : 29
# 결과 : 비만
#
# 이름 : 타차
# 체중 : 83
# 신장 : 194
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 다아
# 체중 : 90
# 신장 : 182
# BMI : 27
# 결과 : 비만
#
# 이름 : 나파
# 체중 : 61
# 신장 : 182
# BMI : 18
# 결과 : 저체중
#
# 이름 : 카마
# 체중 : 43
# 신장 : 159
# BMI : 17
# 결과 : 저체중
#
# 이름 : 사나
# 체중 : 89
# 신장 : 176
# BMI : 28
# 결과 : 비만
#
# 이름 : 사가
# 체중 : 95
# 신장 : 157
# BMI : 38
# 결과 : 비만
#
# 이름 : 하바
# 체중 : 70
# 신장 : 176
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 가아
# 체중 : 72
# 신장 : 161
# BMI : 27
# 결과 : 비만
#
# 이름 : 마라
# 체중 : 57
# 신장 : 185
# BMI : 16
# 결과 : 저체중
#
# 이름 : 자나
# 체중 : 68
# 신장 : 156
# BMI : 27
# 결과 : 비만
#
# 이름 : 가차
# 체중 : 49
# 신장 : 186
# BMI : 14
# 결과 : 저체중
#
# 이름 : 하나
# 체중 : 49
# 신장 : 160
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 가파
# 체중 : 53
# 신장 : 150
# BMI : 23
# 결과 : 과체중
#
# 이름 : 카라
# 체중 : 47
# 신장 : 160
# BMI : 18
# 결과 : 저체중
#
# 이름 : 타타
# 체중 : 45
# 신장 : 153
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 바라
# 체중 : 99
# 신장 : 146
# BMI : 46
# 결과 : 비만
#
# 이름 : 사나
# 체중 : 61
# 신장 : 146
# BMI : 28
# 결과 : 비만
#
# 이름 : 사나
# 체중 : 58
# 신장 : 181
# BMI : 17
# 결과 : 저체중
#
# 이름 : 카타
# 체중 : 55
# 신장 : 155
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 타타
# 체중 : 46
# 신장 : 151
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 가하
# 체중 : 83
# 신장 : 146
# BMI : 38
# 결과 : 비만
#
# 이름 : 마하
# 체중 : 41
# 신장 : 179
# BMI : 12
# 결과 : 저체중
#
# 이름 : 나라
# 체중 : 76
# 신장 : 197
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 나나
# 체중 : 98
# 신장 : 196
# BMI : 25
# 결과 : 비만
#
# 이름 : 아가
# 체중 : 40
# 신장 : 194
# BMI : 10
# 결과 : 저체중
#
# 이름 : 다타
# 체중 : 83
# 신장 : 152
# BMI : 35
# 결과 : 비만
#
# 이름 : 라바
# 체중 : 77
# 신장 : 188
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 하가
# 체중 : 89
# 신장 : 174
# BMI : 29
# 결과 : 비만
#
# 이름 : 다차
# 체중 : 96
# 신장 : 148
# BMI : 43
# 결과 : 비만
#
# 이름 : 아라
# 체중 : 44
# 신장 : 158
# BMI : 17
# 결과 : 저체중
#
# 이름 : 카카
# 체중 : 73
# 신장 : 176
# BMI : 23
# 결과 : 과체중
#
# 이름 : 파차
# 체중 : 79
# 신장 : 159
# BMI : 31
# 결과 : 비만
#
# 이름 : 자마
# 체중 : 84
# 신장 : 173
# BMI : 28
# 결과 : 비만
#
# 이름 : 아하
# 체중 : 63
# 신장 : 156
# BMI : 25
# 결과 : 비만
#
# 이름 : 아자
# 체중 : 94
# 신장 : 140
# BMI : 47
# 결과 : 비만
#
# 이름 : 타사
# 체중 : 72
# 신장 : 186
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 파자
# 체중 : 77
# 신장 : 197
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 다나
# 체중 : 56
# 신장 : 161
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 타라
# 체중 : 46
# 신장 : 167
# BMI : 16
# 결과 : 저체중
#
# 이름 : 하라
# 체중 : 44
# 신장 : 187
# BMI : 12
# 결과 : 저체중
#
# 이름 : 바차
# 체중 : 70
# 신장 : 175
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 파사
# 체중 : 41
# 신장 : 144
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 하바
# 체중 : 68
# 신장 : 192
# BMI : 18
# 결과 : 저체중
#
# 이름 : 마하
# 체중 : 60
# 신장 : 192
# BMI : 16
# 결과 : 저체중
#
# 이름 : 바바
# 체중 : 66
# 신장 : 141
# BMI : 33
# 결과 : 비만
#
# 이름 : 차타
# 체중 : 40
# 신장 : 146
# BMI : 18
# 결과 : 저체중
#
# 이름 : 아라
# 체중 : 50
# 신장 : 154
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 카사
# 체중 : 46
# 신장 : 184
# BMI : 13
# 결과 : 저체중
#
# 이름 : 차가
# 체중 : 69
# 신장 : 168
# BMI : 24
# 결과 : 과체중
#
# 이름 : 바자
# 체중 : 97
# 신장 : 172
# BMI : 32
# 결과 : 비만
#
# 이름 : 파아
# 체중 : 42
# 신장 : 190
# BMI : 11
# 결과 : 저체중
#
# 이름 : 아하
# 체중 : 79
# 신장 : 199
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 가가
# 체중 : 61
# 신장 : 160
# BMI : 23
# 결과 : 과체중
#
# 이름 : 자카
# 체중 : 91
# 신장 : 156
# BMI : 37
# 결과 : 비만
#
# 이름 : 하자
# 체중 : 65
# 신장 : 167
# BMI : 23
# 결과 : 과체중
#
# 이름 : 가라
# 체중 : 65
# 신장 : 171
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 바타
# 체중 : 57
# 신장 : 152
# BMI : 24
# 결과 : 과체중
#
# 이름 : 타차
# 체중 : 95
# 신장 : 191
# BMI : 26
# 결과 : 비만
#
# 이름 : 마자
# 체중 : 53
# 신장 : 194
# BMI : 14
# 결과 : 저체중
#
# 이름 : 다아
# 체중 : 88
# 신장 : 182
# BMI : 26
# 결과 : 비만
#
# 이름 : 차타
# 체중 : 76
# 신장 : 164
# BMI : 28
# 결과 : 비만
#
# 이름 : 카파
# 체중 : 72
# 신장 : 181
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 파바
# 체중 : 85
# 신장 : 184
# BMI : 25
# 결과 : 비만
#
# 이름 : 가차
# 체중 : 68
# 신장 : 188
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 자하
# 체중 : 50
# 신장 : 163
# BMI : 18
# 결과 : 저체중
#
# 이름 : 타가
# 체중 : 61
# 신장 : 170
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 자카
# 체중 : 49
# 신장 : 161
# BMI : 18
# 결과 : 저체중
#
# 이름 : 차나
# 체중 : 87
# 신장 : 198
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 사바
# 체중 : 89
# 신장 : 178
# BMI : 28
# 결과 : 비만
#
# 이름 : 파자
# 체중 : 74
# 신장 : 151
# BMI : 32
# 결과 : 비만
#
# 이름 : 카사
# 체중 : 44
# 신장 : 185
# BMI : 12
# 결과 : 저체중
#
# 이름 : 카하
# 체중 : 42
# 신장 : 173
# BMI : 14
# 결과 : 저체중
#
# 이름 : 차차
# 체중 : 96
# 신장 : 144
# BMI : 46
# 결과 : 비만
#
# 이름 : 하차
# 체중 : 77
# 신장 : 174
# BMI : 25
# 결과 : 비만
#
# 이름 : 나타
# 체중 : 84
# 신장 : 145
# BMI : 39
# 결과 : 비만
#
# 이름 : 마차
# 체중 : 91
# 신장 : 142
# BMI : 45
# 결과 : 비만
#
# 이름 : 다자
# 체중 : 80
# 신장 : 186
# BMI : 23
# 결과 : 과체중
#
# 이름 : 자차
# 체중 : 64
# 신장 : 196
# BMI : 16
# 결과 : 저체중
#
# 이름 : 차사
# 체중 : 70
# 신장 : 173
# BMI : 23
# 결과 : 과체중
#
# 이름 : 가하
# 체중 : 82
# 신장 : 152
# BMI : 35
# 결과 : 비만
#
# 이름 : 타타
# 체중 : 57
# 신장 : 145
# BMI : 27
# 결과 : 비만
#
# 이름 : 다자
# 체중 : 51
# 신장 : 186
# BMI : 14
# 결과 : 저체중
#
# 이름 : 자라
# 체중 : 97
# 신장 : 197
# BMI : 24
# 결과 : 과체중
#
# 이름 : 카파
# 체중 : 69
# 신장 : 163
# BMI : 25
# 결과 : 비만
#
# 이름 : 아가
# 체중 : 88
# 신장 : 177
# BMI : 28
# 결과 : 비만
#
# 이름 : 나파
# 체중 : 79
# 신장 : 179
# BMI : 24
# 결과 : 과체중
#
# 이름 : 자차
# 체중 : 55
# 신장 : 196
# BMI : 14
# 결과 : 저체중
#
# 이름 : 마다
# 체중 : 51
# 신장 : 142
# BMI : 25
# 결과 : 비만
#
# 이름 : 파파
# 체중 : 96
# 신장 : 154
# BMI : 40
# 결과 : 비만
#
# 이름 : 아바
# 체중 : 85
# 신장 : 194
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 다마
# 체중 : 70
# 신장 : 157
# BMI : 28
# 결과 : 비만
#
# 이름 : 카차
# 체중 : 87
# 신장 : 190
# BMI : 24
# 결과 : 과체중
#
# 이름 : 파차
# 체중 : 40
# 신장 : 165
# BMI : 14
# 결과 : 저체중
#
# 이름 : 아차
# 체중 : 58
# 신장 : 184
# BMI : 17
# 결과 : 저체중
#
# 이름 : 가파
# 체중 : 89
# 신장 : 192
# BMI : 24
# 결과 : 과체중
#
# 이름 : 마바
# 체중 : 65
# 신장 : 190
# BMI : 18
# 결과 : 저체중
#
# 이름 : 가사
# 체중 : 46
# 신장 : 166
# BMI : 16
# 결과 : 저체중
#
# 이름 : 자카
# 체중 : 88
# 신장 : 147
# BMI : 40
# 결과 : 비만
#
# 이름 : 다타
# 체중 : 82
# 신장 : 155
# BMI : 34
# 결과 : 비만
#
# 이름 : 자다
# 체중 : 58
# 신장 : 158
# BMI : 23
# 결과 : 과체중
#
# 이름 : 카차
# 체중 : 60
# 신장 : 191
# BMI : 16
# 결과 : 저체중
#
# 이름 : 사다
# 체중 : 41
# 신장 : 160
# BMI : 16
# 결과 : 저체중
#
# 이름 : 마자
# 체중 : 94
# 신장 : 150
# BMI : 41
# 결과 : 비만
#
# 이름 : 다자
# 체중 : 72
# 신장 : 165
# BMI : 26
# 결과 : 비만
#
# 이름 : 아자
# 체중 : 59
# 신장 : 149
# BMI : 26
# 결과 : 비만
#
# 이름 : 하카
# 체중 : 68
# 신장 : 163
# BMI : 25
# 결과 : 비만
#
# 이름 : 가하
# 체중 : 71
# 신장 : 164
# BMI : 26
# 결과 : 비만
#
# 이름 : 가차
# 체중 : 89
# 신장 : 141
# BMI : 44
# 결과 : 비만
#
# 이름 : 타나
# 체중 : 81
# 신장 : 145
# BMI : 38
# 결과 : 비만
#
# 이름 : 자하
# 체중 : 88
# 신장 : 185
# BMI : 25
# 결과 : 비만
#
# 이름 : 다파
# 체중 : 90
# 신장 : 154
# BMI : 37
# 결과 : 비만
#
# 이름 : 아자
# 체중 : 98
# 신장 : 176
# BMI : 31
# 결과 : 비만
#
# 이름 : 마타
# 체중 : 51
# 신장 : 174
# BMI : 16
# 결과 : 저체중
#
# 이름 : 사타
# 체중 : 53
# 신장 : 190
# BMI : 14
# 결과 : 저체중
#
# 이름 : 하카
# 체중 : 45
# 신장 : 175
# BMI : 14
# 결과 : 저체중
#
# 이름 : 바사
# 체중 : 55
# 신장 : 179
# BMI : 17
# 결과 : 저체중
#
# 이름 : 사자
# 체중 : 43
# 신장 : 153
# BMI : 18
# 결과 : 저체중
#
# 이름 : 자하
# 체중 : 81
# 신장 : 178
# BMI : 25
# 결과 : 비만
#
# 이름 : 카파
# 체중 : 86
# 신장 : 199
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 다바
# 체중 : 56
# 신장 : 161
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 다가
# 체중 : 63
# 신장 : 170
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 파마
# 체중 : 63
# 신장 : 164
# BMI : 23
# 결과 : 과체중
#
# 이름 : 타하
# 체중 : 65
# 신장 : 142
# BMI : 32
# 결과 : 비만
#
# 이름 : 라카
# 체중 : 59
# 신장 : 141
# BMI : 29
# 결과 : 비만
#
# 이름 : 마파
# 체중 : 71
# 신장 : 177
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 카타
# 체중 : 93
# 신장 : 196
# BMI : 24
# 결과 : 과체중
#
# 이름 : 타마
# 체중 : 94
# 신장 : 181
# BMI : 28
# 결과 : 비만
#
# 이름 : 자타
# 체중 : 53
# 신장 : 149
# BMI : 23
# 결과 : 과체중
#
# 이름 : 자바
# 체중 : 93
# 신장 : 170
# BMI : 32
# 결과 : 비만
#
# 이름 : 라하
# 체중 : 72
# 신장 : 171
# BMI : 24
# 결과 : 과체중
#
# 이름 : 카자
# 체중 : 54
# 신장 : 172
# BMI : 18
# 결과 : 저체중
#
# 이름 : 다나
# 체중 : 77
# 신장 : 156
# BMI : 31
# 결과 : 비만
#
# 이름 : 다자
# 체중 : 59
# 신장 : 199
# BMI : 14
# 결과 : 저체중
#
# 이름 : 다라
# 체중 : 67
# 신장 : 189
# BMI : 18
# 결과 : 저체중
#
# 이름 : 파가
# 체중 : 99
# 신장 : 155
# BMI : 41
# 결과 : 비만
#
# 이름 : 자차
# 체중 : 73
# 신장 : 198
# BMI : 18
# 결과 : 저체중
#
# 이름 : 타카
# 체중 : 61
# 신장 : 172
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 나차
# 체중 : 78
# 신장 : 147
# BMI : 36
# 결과 : 비만
#
# 이름 : 자자
# 체중 : 64
# 신장 : 151
# BMI : 28
# 결과 : 비만
#
# 이름 : 파카
# 체중 : 66
# 신장 : 181
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 하마
# 체중 : 87
# 신장 : 192
# BMI : 23
# 결과 : 과체중
#
# 이름 : 파타
# 체중 : 48
# 신장 : 153
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 파아
# 체중 : 76
# 신장 : 161
# BMI : 29
# 결과 : 비만
#
# 이름 : 사차
# 체중 : 82
# 신장 : 155
# BMI : 34
# 결과 : 비만
#
# 이름 : 다다
# 체중 : 80
# 신장 : 196
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 라사
# 체중 : 73
# 신장 : 141
# BMI : 36
# 결과 : 비만
#
# 이름 : 라나
# 체중 : 80
# 신장 : 163
# BMI : 30
# 결과 : 비만
#
# 이름 : 다가
# 체중 : 87
# 신장 : 184
# BMI : 25
# 결과 : 비만
#
# 이름 : 자마
# 체중 : 76
# 신장 : 192
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 마아
# 체중 : 58
# 신장 : 144
# BMI : 27
# 결과 : 비만
#
# 이름 : 가타
# 체중 : 41
# 신장 : 167
# BMI : 14
# 결과 : 저체중
#
# 이름 : 나사
# 체중 : 57
# 신장 : 196
# BMI : 14
# 결과 : 저체중
#
# 이름 : 다마
# 체중 : 90
# 신장 : 149
# BMI : 40
# 결과 : 비만
#
# 이름 : 사다
# 체중 : 93
# 신장 : 144
# BMI : 44
# 결과 : 비만
#
# 이름 : 바가
# 체중 : 79
# 신장 : 144
# BMI : 38
# 결과 : 비만
#
# 이름 : 타다
# 체중 : 87
# 신장 : 143
# BMI : 42
# 결과 : 비만
#
# 이름 : 사자
# 체중 : 41
# 신장 : 171
# BMI : 14
# 결과 : 저체중
#
# 이름 : 다나
# 체중 : 62
# 신장 : 174
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 아자
# 체중 : 53
# 신장 : 168
# BMI : 18
# 결과 : 저체중
#
# 이름 : 나가
# 체중 : 80
# 신장 : 156
# BMI : 32
# 결과 : 비만
#
# 이름 : 바마
# 체중 : 45
# 신장 : 148
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 차라
# 체중 : 51
# 신장 : 189
# BMI : 14
# 결과 : 저체중
#
# 이름 : 하차
# 체중 : 61
# 신장 : 155
# BMI : 25
# 결과 : 비만
#
# 이름 : 자마
# 체중 : 92
# 신장 : 179
# BMI : 28
# 결과 : 비만
#
# 이름 : 자다
# 체중 : 52
# 신장 : 158
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 다마
# 체중 : 58
# 신장 : 193
# BMI : 15
# 결과 : 저체중
#
# 이름 : 하마
# 체중 : 68
# 신장 : 165
# BMI : 24
# 결과 : 과체중
#
# 이름 : 아사
# 체중 : 47
# 신장 : 192
# BMI : 12
# 결과 : 저체중
#
# 이름 : 아나
# 체중 : 85
# 신장 : 161
# BMI : 32
# 결과 : 비만
#
# 이름 : 타파
# 체중 : 76
# 신장 : 157
# BMI : 30
# 결과 : 비만
#
# 이름 : 마자
# 체중 : 79
# 신장 : 162
# BMI : 30
# 결과 : 비만
#
# 이름 : 바타
# 체중 : 96
# 신장 : 188
# BMI : 27
# 결과 : 비만
#
# 이름 : 마나
# 체중 : 45
# 신장 : 186
# BMI : 13
# 결과 : 저체중
#
# 이름 : 차자
# 체중 : 54
# 신장 : 164
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 다아
# 체중 : 83
# 신장 : 147
# BMI : 38
# 결과 : 비만
#
# 이름 : 파타
# 체중 : 47
# 신장 : 153
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 하자
# 체중 : 75
# 신장 : 171
# BMI : 25
# 결과 : 비만
#
# 이름 : 파가
# 체중 : 49
# 신장 : 162
# BMI : 18
# 결과 : 저체중
#
# 이름 : 사자
# 체중 : 77
# 신장 : 162
# BMI : 29
# 결과 : 비만
#
# 이름 : 차하
# 체중 : 55
# 신장 : 154
# BMI : 23
# 결과 : 과체중
#
# 이름 : 사파
# 체중 : 59
# 신장 : 187
# BMI : 16
# 결과 : 저체중
#
# 이름 : 자마
# 체중 : 47
# 신장 : 171
# BMI : 16
# 결과 : 저체중
#
# 이름 : 다하
# 체중 : 97
# 신장 : 185
# BMI : 28
# 결과 : 비만
#
# 이름 : 파가
# 체중 : 81
# 신장 : 193
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 하타
# 체중 : 50
# 신장 : 179
# BMI : 15
# 결과 : 저체중
#
# 이름 : 아가
# 체중 : 88
# 신장 : 164
# BMI : 32
# 결과 : 비만
#
# 이름 : 가사
# 체중 : 97
# 신장 : 145
# BMI : 46
# 결과 : 비만
#
# 이름 : 라하
# 체중 : 72
# 신장 : 143
# BMI : 35
# 결과 : 비만
#
# 이름 : 나라
# 체중 : 49
# 신장 : 169
# BMI : 17
# 결과 : 저체중
#
# 이름 : 다바
# 체중 : 88
# 신장 : 182
# BMI : 26
# 결과 : 비만
#
# 이름 : 다바
# 체중 : 63
# 신장 : 173
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 바바
# 체중 : 73
# 신장 : 153
# BMI : 31
# 결과 : 비만
#
# 이름 : 나라
# 체중 : 61
# 신장 : 190
# BMI : 16
# 결과 : 저체중
#
# 이름 : 카라
# 체중 : 63
# 신장 : 152
# BMI : 27
# 결과 : 비만
#
# 이름 : 아하
# 체중 : 75
# 신장 : 145
# BMI : 35
# 결과 : 비만
#
# 이름 : 나사
# 체중 : 74
# 신장 : 167
# BMI : 26
# 결과 : 비만
#
# 이름 : 타차
# 체중 : 67
# 신장 : 151
# BMI : 29
# 결과 : 비만
#
# 이름 : 다라
# 체중 : 92
# 신장 : 161
# BMI : 35
# 결과 : 비만
#
# 이름 : 타자
# 체중 : 84
# 신장 : 169
# BMI : 29
# 결과 : 비만
#
# 이름 : 하하
# 체중 : 63
# 신장 : 189
# BMI : 17
# 결과 : 저체중
#
# 이름 : 파마
# 체중 : 56
# 신장 : 166
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 다사
# 체중 : 69
# 신장 : 152
# BMI : 29
# 결과 : 비만
#
# 이름 : 차차
# 체중 : 82
# 신장 : 157
# BMI : 33
# 결과 : 비만
#
# 이름 : 가가
# 체중 : 47
# 신장 : 199
# BMI : 11
# 결과 : 저체중
#
# 이름 : 차차
# 체중 : 89
# 신장 : 141
# BMI : 44
# 결과 : 비만
#
# 이름 : 사나
# 체중 : 94
# 신장 : 174
# BMI : 31
# 결과 : 비만
#
# 이름 : 파라
# 체중 : 87
# 신장 : 198
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 다나
# 체중 : 52
# 신장 : 171
# BMI : 17
# 결과 : 저체중
#
# 이름 : 나라
# 체중 : 78
# 신장 : 147
# BMI : 36
# 결과 : 비만
#
# 이름 : 타바
# 체중 : 97
# 신장 : 161
# BMI : 37
# 결과 : 비만
#
# 이름 : 가가
# 체중 : 74
# 신장 : 178
# BMI : 23
# 결과 : 과체중
#
# 이름 : 아하
# 체중 : 86
# 신장 : 150
# BMI : 38
# 결과 : 비만
#
# 이름 : 가카
# 체중 : 85
# 신장 : 173
# BMI : 28
# 결과 : 비만
#
# 이름 : 사차
# 체중 : 66
# 신장 : 182
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 차사
# 체중 : 54
# 신장 : 198
# BMI : 13
# 결과 : 저체중
#
# 이름 : 다타
# 체중 : 60
# 신장 : 172
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 마차
# 체중 : 83
# 신장 : 148
# BMI : 37
# 결과 : 비만
#
# 이름 : 타아
# 체중 : 86
# 신장 : 189
# BMI : 24
# 결과 : 과체중
#
# 이름 : 가카
# 체중 : 64
# 신장 : 192
# BMI : 17
# 결과 : 저체중
#
# 이름 : 카바
# 체중 : 44
# 신장 : 141
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 다다
# 체중 : 96
# 신장 : 183
# BMI : 28
# 결과 : 비만
#
# 이름 : 자다
# 체중 : 67
# 신장 : 146
# BMI : 31
# 결과 : 비만
#
# 이름 : 바자
# 체중 : 52
# 신장 : 142
# BMI : 25
# 결과 : 비만
#
# 이름 : 아나
# 체중 : 51
# 신장 : 185
# BMI : 14
# 결과 : 저체중
#
# 이름 : 차사
# 체중 : 60
# 신장 : 195
# BMI : 15
# 결과 : 저체중
#
# 이름 : 자사
# 체중 : 58
# 신장 : 165
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 다나
# 체중 : 54
# 신장 : 172
# BMI : 18
# 결과 : 저체중
#
# 이름 : 라하
# 체중 : 57
# 신장 : 182
# BMI : 17
# 결과 : 저체중
#
# 이름 : 카자
# 체중 : 42
# 신장 : 150
# BMI : 18
# 결과 : 저체중
#
# 이름 : 사하
# 체중 : 94
# 신장 : 143
# BMI : 45
# 결과 : 비만
#
# 이름 : 자타
# 체중 : 99
# 신장 : 167
# BMI : 35
# 결과 : 비만
#
# 이름 : 라하
# 체중 : 84
# 신장 : 199
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 카자
# 체중 : 41
# 신장 : 160
# BMI : 16
# 결과 : 저체중
#
# 이름 : 파다
# 체중 : 97
# 신장 : 144
# BMI : 46
# 결과 : 비만
#
# 이름 : 마하
# 체중 : 54
# 신장 : 197
# BMI : 13
# 결과 : 저체중
#
# 이름 : 다라
# 체중 : 75
# 신장 : 170
# BMI : 25
# 결과 : 비만
#
# 이름 : 차하
# 체중 : 79
# 신장 : 181
# BMI : 24
# 결과 : 과체중
#
# 이름 : 타파
# 체중 : 62
# 신장 : 166
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 파바
# 체중 : 96
# 신장 : 167
# BMI : 34
# 결과 : 비만
#
# 이름 : 카차
# 체중 : 75
# 신장 : 172
# BMI : 25
# 결과 : 비만
#
# 이름 : 마바
# 체중 : 96
# 신장 : 180
# BMI : 29
# 결과 : 비만
#
# 이름 : 바하
# 체중 : 62
# 신장 : 155
# BMI : 25
# 결과 : 비만
#
# 이름 : 라사
# 체중 : 97
# 신장 : 176
# BMI : 31
# 결과 : 비만
#
# 이름 : 아마
# 체중 : 73
# 신장 : 187
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 다하
# 체중 : 72
# 신장 : 179
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 마나
# 체중 : 64
# 신장 : 148
# BMI : 29
# 결과 : 비만
#
# 이름 : 아타
# 체중 : 80
# 신장 : 193
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 마라
# 체중 : 92
# 신장 : 156
# BMI : 37
# 결과 : 비만
#
# 이름 : 가차
# 체중 : 84
# 신장 : 156
# BMI : 34
# 결과 : 비만
#
# 이름 : 다하
# 체중 : 87
# 신장 : 171
# BMI : 29
# 결과 : 비만
#
# 이름 : 나파
# 체중 : 60
# 신장 : 183
# BMI : 17
# 결과 : 저체중
#
# 이름 : 다타
# 체중 : 70
# 신장 : 158
# BMI : 28
# 결과 : 비만
#
# 이름 : 사라
# 체중 : 66
# 신장 : 186
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 자사
# 체중 : 43
# 신장 : 173
# BMI : 14
# 결과 : 저체중
#
# 이름 : 타바
# 체중 : 53
# 신장 : 197
# BMI : 13
# 결과 : 저체중
#
# 이름 : 파자
# 체중 : 99
# 신장 : 177
# BMI : 31
# 결과 : 비만
#
# 이름 : 나사
# 체중 : 81
# 신장 : 145
# BMI : 38
# 결과 : 비만
#
# 이름 : 라라
# 체중 : 59
# 신장 : 152
# BMI : 25
# 결과 : 비만
#
# 이름 : 타마
# 체중 : 94
# 신장 : 184
# BMI : 27
# 결과 : 비만
#
# 이름 : 타차
# 체중 : 46
# 신장 : 197
# BMI : 11
# 결과 : 저체중
#
# 이름 : 나마
# 체중 : 89
# 신장 : 142
# BMI : 44
# 결과 : 비만
#
# 이름 : 파라
# 체중 : 99
# 신장 : 167
# BMI : 35
# 결과 : 비만
#
# 이름 : 아라
# 체중 : 77
# 신장 : 192
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 카나
# 체중 : 55
# 신장 : 188
# BMI : 15
# 결과 : 저체중
#
# 이름 : 하하
# 체중 : 62
# 신장 : 156
# BMI : 25
# 결과 : 비만
#
# 이름 : 차마
# 체중 : 72
# 신장 : 145
# BMI : 34
# 결과 : 비만
#
# 이름 : 가바
# 체중 : 53
# 신장 : 184
# BMI : 15
# 결과 : 저체중
#
# 이름 : 마가
# 체중 : 62
# 신장 : 167
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 카라
# 체중 : 64
# 신장 : 198
# BMI : 16
# 결과 : 저체중
#
# 이름 : 카가
# 체중 : 56
# 신장 : 190
# BMI : 15
# 결과 : 저체중
#
# 이름 : 가타
# 체중 : 86
# 신장 : 188
# BMI : 24
# 결과 : 과체중
#
# 이름 : 다차
# 체중 : 88
# 신장 : 154
# BMI : 37
# 결과 : 비만
#
# 이름 : 파차
# 체중 : 80
# 신장 : 165
# BMI : 29
# 결과 : 비만
#
# 이름 : 라마
# 체중 : 46
# 신장 : 147
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 사차
# 체중 : 97
# 신장 : 155
# BMI : 40
# 결과 : 비만
#
# 이름 : 다차
# 체중 : 78
# 신장 : 149
# BMI : 35
# 결과 : 비만
#
# 이름 : 하마
# 체중 : 54
# 신장 : 145
# BMI : 25
# 결과 : 비만
#
# 이름 : 타하
# 체중 : 51
# 신장 : 188
# BMI : 14
# 결과 : 저체중
#
# 이름 : 마파
# 체중 : 60
# 신장 : 148
# BMI : 27
# 결과 : 비만
#
# 이름 : 차사
# 체중 : 72
# 신장 : 141
# BMI : 36
# 결과 : 비만
#
# 이름 : 파자
# 체중 : 71
# 신장 : 188
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 타차
# 체중 : 75
# 신장 : 185
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 차타
# 체중 : 54
# 신장 : 195
# BMI : 14
# 결과 : 저체중
#
# 이름 : 마파
# 체중 : 84
# 신장 : 174
# BMI : 27
# 결과 : 비만
#
# 이름 : 라차
# 체중 : 58
# 신장 : 189
# BMI : 16
# 결과 : 저체중
#
# 이름 : 카아
# 체중 : 74
# 신장 : 173
# BMI : 24
# 결과 : 과체중
#
# 이름 : 아라
# 체중 : 95
# 신장 : 150
# BMI : 42
# 결과 : 비만
#
# 이름 : 다자
# 체중 : 81
# 신장 : 174
# BMI : 26
# 결과 : 비만
#
# 이름 : 나라
# 체중 : 90
# 신장 : 195
# BMI : 23
# 결과 : 과체중
#
# 이름 : 차자
# 체중 : 70
# 신장 : 168
# BMI : 24
# 결과 : 과체중
#
# 이름 : 차라
# 체중 : 67
# 신장 : 148
# BMI : 30
# 결과 : 비만
#
# 이름 : 파아
# 체중 : 46
# 신장 : 189
# BMI : 12
# 결과 : 저체중
#
# 이름 : 가마
# 체중 : 90
# 신장 : 198
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 가마
# 체중 : 63
# 신장 : 150
# BMI : 28
# 결과 : 비만
#
# 이름 : 가라
# 체중 : 54
# 신장 : 147
# BMI : 24
# 결과 : 과체중
#
# 이름 : 나사
# 체중 : 93
# 신장 : 153
# BMI : 39
# 결과 : 비만
#
# 이름 : 타다
# 체중 : 95
# 신장 : 173
# BMI : 31
# 결과 : 비만
#
# 이름 : 아타
# 체중 : 55
# 신장 : 181
# BMI : 16
# 결과 : 저체중
#
# 이름 : 사카
# 체중 : 75
# 신장 : 157
# BMI : 30
# 결과 : 비만
#
# 이름 : 자카
# 체중 : 62
# 신장 : 160
# BMI : 24
# 결과 : 과체중
#
# 이름 : 차나
# 체중 : 96
# 신장 : 173
# BMI : 32
# 결과 : 비만
#
# 이름 : 마카
# 체중 : 87
# 신장 : 194
# BMI : 23
# 결과 : 과체중
#
# 이름 : 라다
# 체중 : 60
# 신장 : 155
# BMI : 24
# 결과 : 과체중
#
# 이름 : 차파
# 체중 : 40
# 신장 : 142
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 파다
# 체중 : 69
# 신장 : 147
# BMI : 31
# 결과 : 비만
#
# 이름 : 가라
# 체중 : 82
# 신장 : 160
# BMI : 32
# 결과 : 비만
#
# 이름 : 하다
# 체중 : 92
# 신장 : 175
# BMI : 30
# 결과 : 비만
#
# 이름 : 카라
# 체중 : 62
# 신장 : 169
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 자타
# 체중 : 91
# 신장 : 175
# BMI : 29
# 결과 : 비만
#
# 이름 : 파타
# 체중 : 96
# 신장 : 182
# BMI : 28
# 결과 : 비만
#
# 이름 : 나하
# 체중 : 49
# 신장 : 179
# BMI : 15
# 결과 : 저체중
#
# 이름 : 사카
# 체중 : 63
# 신장 : 187
# BMI : 18
# 결과 : 저체중
#
# 이름 : 차나
# 체중 : 98
# 신장 : 159
# BMI : 38
# 결과 : 비만
#
# 이름 : 라나
# 체중 : 84
# 신장 : 196
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 타나
# 체중 : 49
# 신장 : 185
# BMI : 14
# 결과 : 저체중
#
# 이름 : 차하
# 체중 : 52
# 신장 : 175
# BMI : 16
# 결과 : 저체중
#
# 이름 : 나마
# 체중 : 96
# 신장 : 186
# BMI : 27
# 결과 : 비만
#
# 이름 : 나사
# 체중 : 80
# 신장 : 180
# BMI : 24
# 결과 : 과체중
#
# 이름 : 자나
# 체중 : 73
# 신장 : 179
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 차사
# 체중 : 45
# 신장 : 177
# BMI : 14
# 결과 : 저체중
#
# 이름 : 가다
# 체중 : 44
# 신장 : 146
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 가카
# 체중 : 74
# 신장 : 154
# BMI : 31
# 결과 : 비만
#
# 이름 : 하라
# 체중 : 79
# 신장 : 168
# BMI : 27
# 결과 : 비만
#
# 이름 : 하가
# 체중 : 69
# 신장 : 164
# BMI : 25
# 결과 : 비만
#
# 이름 : 하타
# 체중 : 98
# 신장 : 188
# BMI : 27
# 결과 : 비만
#
# 이름 : 바아
# 체중 : 45
# 신장 : 165
# BMI : 16
# 결과 : 저체중
#
# 이름 : 마마
# 체중 : 59
# 신장 : 163
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 사아
# 체중 : 59
# 신장 : 175
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 자사
# 체중 : 73
# 신장 : 181
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 아타
# 체중 : 70
# 신장 : 146
# BMI : 32
# 결과 : 비만
#
# 이름 : 다가
# 체중 : 71
# 신장 : 140
# BMI : 36
# 결과 : 비만
#
# 이름 : 사마
# 체중 : 91
# 신장 : 194
# BMI : 24
# 결과 : 과체중
#
# 이름 : 타사
# 체중 : 89
# 신장 : 168
# BMI : 31
# 결과 : 비만
#
# 이름 : 마라
# 체중 : 80
# 신장 : 174
# BMI : 26
# 결과 : 비만
#
# 이름 : 다다
# 체중 : 49
# 신장 : 198
# BMI : 12
# 결과 : 저체중
#
# 이름 : 아나
# 체중 : 79
# 신장 : 165
# BMI : 29
# 결과 : 비만
#
# 이름 : 가마
# 체중 : 61
# 신장 : 189
# BMI : 17
# 결과 : 저체중
#
# 이름 : 카가
# 체중 : 44
# 신장 : 161
# BMI : 16
# 결과 : 저체중
#
# 이름 : 가라
# 체중 : 92
# 신장 : 183
# BMI : 27
# 결과 : 비만
#
# 이름 : 카파
# 체중 : 63
# 신장 : 142
# BMI : 31
# 결과 : 비만
#
# 이름 : 파파
# 체중 : 85
# 신장 : 156
# BMI : 34
# 결과 : 비만
#
# 이름 : 바라
# 체중 : 80
# 신장 : 186
# BMI : 23
# 결과 : 과체중
#
# 이름 : 카자
# 체중 : 65
# 신장 : 148
# BMI : 29
# 결과 : 비만
#
# 이름 : 다아
# 체중 : 43
# 신장 : 189
# BMI : 12
# 결과 : 저체중
#
# 이름 : 자하
# 체중 : 58
# 신장 : 157
# BMI : 23
# 결과 : 과체중
#
# 이름 : 사카
# 체중 : 94
# 신장 : 169
# BMI : 32
# 결과 : 비만
#
# 이름 : 바가
# 체중 : 76
# 신장 : 160
# BMI : 29
# 결과 : 비만
#
# 이름 : 가나
# 체중 : 77
# 신장 : 144
# BMI : 37
# 결과 : 비만
#
# 이름 : 사사
# 체중 : 50
# 신장 : 185
# BMI : 14
# 결과 : 저체중
#
# 이름 : 하카
# 체중 : 65
# 신장 : 161
# BMI : 25
# 결과 : 비만
#
# 이름 : 카가
# 체중 : 77
# 신장 : 173
# BMI : 25
# 결과 : 비만
#
# 이름 : 바라
# 체중 : 83
# 신장 : 185
# BMI : 24
# 결과 : 과체중
#
# 이름 : 가다
# 체중 : 51
# 신장 : 175
# BMI : 16
# 결과 : 저체중
#
# 이름 : 마카
# 체중 : 79
# 신장 : 151
# BMI : 34
# 결과 : 비만
#
# 이름 : 나파
# 체중 : 67
# 신장 : 195
# BMI : 17
# 결과 : 저체중
#
# 이름 : 라자
# 체중 : 65
# 신장 : 152
# BMI : 28
# 결과 : 비만
#
# 이름 : 아타
# 체중 : 86
# 신장 : 154
# BMI : 36
# 결과 : 비만
#
# 이름 : 다아
# 체중 : 69
# 신장 : 176
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 파라
# 체중 : 68
# 신장 : 193
# BMI : 18
# 결과 : 저체중
#
# 이름 : 나다
# 체중 : 68
# 신장 : 173
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 카나
# 체중 : 84
# 신장 : 170
# BMI : 29
# 결과 : 비만
#
# 이름 : 라파
# 체중 : 61
# 신장 : 158
# BMI : 24
# 결과 : 과체중
#
# 이름 : 라아
# 체중 : 94
# 신장 : 197
# BMI : 24
# 결과 : 과체중
#
# 이름 : 다사
# 체중 : 99
# 신장 : 181
# BMI : 30
# 결과 : 비만
#
# 이름 : 아차
# 체중 : 80
# 신장 : 142
# BMI : 39
# 결과 : 비만
#
# 이름 : 차아
# 체중 : 58
# 신장 : 174
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 바하
# 체중 : 97
# 신장 : 180
# BMI : 29
# 결과 : 비만
#
# 이름 : 차라
# 체중 : 69
# 신장 : 161
# BMI : 26
# 결과 : 비만
#
# 이름 : 바타
# 체중 : 69
# 신장 : 161
# BMI : 26
# 결과 : 비만
#
# 이름 : 가나
# 체중 : 75
# 신장 : 184
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 마라
# 체중 : 62
# 신장 : 192
# BMI : 16
# 결과 : 저체중
#
# 이름 : 자파
# 체중 : 81
# 신장 : 144
# BMI : 39
# 결과 : 비만
#
# 이름 : 파가
# 체중 : 84
# 신장 : 143
# BMI : 41
# 결과 : 비만
#
# 이름 : 다나
# 체중 : 78
# 신장 : 168
# BMI : 27
# 결과 : 비만
#
# 이름 : 마바
# 체중 : 62
# 신장 : 164
# BMI : 23
# 결과 : 과체중
#
# 이름 : 카가
# 체중 : 52
# 신장 : 183
# BMI : 15
# 결과 : 저체중
#
# 이름 : 타다
# 체중 : 79
# 신장 : 179
# BMI : 24
# 결과 : 과체중
#
# 이름 : 하마
# 체중 : 51
# 신장 : 194
# BMI : 13
# 결과 : 저체중
#
# 이름 : 파마
# 체중 : 73
# 신장 : 177
# BMI : 23
# 결과 : 과체중
#
# 이름 : 파바
# 체중 : 76
# 신장 : 181
# BMI : 23
# 결과 : 과체중
#
# 이름 : 마바
# 체중 : 47
# 신장 : 193
# BMI : 12
# 결과 : 저체중
#
# 이름 : 나나
# 체중 : 62
# 신장 : 159
# BMI : 24
# 결과 : 과체중
#
# 이름 : 카타
# 체중 : 76
# 신장 : 156
# BMI : 31
# 결과 : 비만
#
# 이름 : 카마
# 체중 : 57
# 신장 : 176
# BMI : 18
# 결과 : 저체중
#
# 이름 : 아파
# 체중 : 58
# 신장 : 197
# BMI : 14
# 결과 : 저체중
#
# 이름 : 자아
# 체중 : 81
# 신장 : 181
# BMI : 24
# 결과 : 과체중
#
# 이름 : 다바
# 체중 : 81
# 신장 : 149
# BMI : 36
# 결과 : 비만
#
# 이름 : 카파
# 체중 : 67
# 신장 : 142
# BMI : 33
# 결과 : 비만
#
# 이름 : 파자
# 체중 : 96
# 신장 : 173
# BMI : 32
# 결과 : 비만
#
# 이름 : 카자
# 체중 : 56
# 신장 : 195
# BMI : 14
# 결과 : 저체중
#
# 이름 : 차가
# 체중 : 63
# 신장 : 182
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 마바
# 체중 : 57
# 신장 : 179
# BMI : 17
# 결과 : 저체중
#
# 이름 : 나나
# 체중 : 91
# 신장 : 197
# BMI : 23
# 결과 : 과체중
#
# 이름 : 사사
# 체중 : 54
# 신장 : 177
# BMI : 17
# 결과 : 저체중
#
# 이름 : 타가
# 체중 : 68
# 신장 : 152
# BMI : 29
# 결과 : 비만
#
# 이름 : 카하
# 체중 : 65
# 신장 : 144
# BMI : 31
# 결과 : 비만
#
# 이름 : 가나
# 체중 : 81
# 신장 : 148
# BMI : 36
# 결과 : 비만
#
# 이름 : 차차
# 체중 : 47
# 신장 : 159
# BMI : 18
# 결과 : 저체중
#
# 이름 : 차타
# 체중 : 45
# 신장 : 150
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 나나
# 체중 : 43
# 신장 : 151
# BMI : 18
# 결과 : 저체중
#
# 이름 : 나카
# 체중 : 77
# 신장 : 163
# BMI : 28
# 결과 : 비만
#
# 이름 : 사마
# 체중 : 82
# 신장 : 190
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 아라
# 체중 : 45
# 신장 : 140
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 카가
# 체중 : 84
# 신장 : 180
# BMI : 25
# 결과 : 비만
#
# 이름 : 자카
# 체중 : 64
# 신장 : 197
# BMI : 16
# 결과 : 저체중
#
# 이름 : 아카
# 체중 : 88
# 신장 : 157
# BMI : 35
# 결과 : 비만
#
# 이름 : 사하
# 체중 : 49
# 신장 : 195
# BMI : 12
# 결과 : 저체중
#
# 이름 : 라바
# 체중 : 53
# 신장 : 193
# BMI : 14
# 결과 : 저체중
#
# 이름 : 가다
# 체중 : 88
# 신장 : 176
# BMI : 28
# 결과 : 비만
#
# 이름 : 다나
# 체중 : 53
# 신장 : 176
# BMI : 17
# 결과 : 저체중
#
# 이름 : 다다
# 체중 : 64
# 신장 : 170
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 나사
# 체중 : 84
# 신장 : 198
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 가라
# 체중 : 70
# 신장 : 188
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 파자
# 체중 : 45
# 신장 : 165
# BMI : 16
# 결과 : 저체중
#
# 이름 : 타다
# 체중 : 73
# 신장 : 145
# BMI : 34
# 결과 : 비만
#
# 이름 : 다라
# 체중 : 62
# 신장 : 173
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 바차
# 체중 : 75
# 신장 : 185
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 나다
# 체중 : 65
# 신장 : 188
# BMI : 18
# 결과 : 저체중
#
# 이름 : 라자
# 체중 : 66
# 신장 : 164
# BMI : 24
# 결과 : 과체중
#
# 이름 : 바라
# 체중 : 44
# 신장 : 185
# BMI : 12
# 결과 : 저체중
#
# 이름 : 자마
# 체중 : 47
# 신장 : 158
# BMI : 18
# 결과 : 저체중
#
# 이름 : 다다
# 체중 : 92
# 신장 : 197
# BMI : 23
# 결과 : 과체중
#
# 이름 : 아차
# 체중 : 63
# 신장 : 163
# BMI : 23
# 결과 : 과체중
#
# 이름 : 파자
# 체중 : 44
# 신장 : 144
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 바나
# 체중 : 51
# 신장 : 147
# BMI : 23
# 결과 : 과체중
#
# 이름 : 가타
# 체중 : 96
# 신장 : 146
# BMI : 45
# 결과 : 비만
#
# 이름 : 바자
# 체중 : 77
# 신장 : 143
# BMI : 37
# 결과 : 비만
#
# 이름 : 가라
# 체중 : 52
# 신장 : 146
# BMI : 24
# 결과 : 과체중
#
# 이름 : 아아
# 체중 : 63
# 신장 : 175
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 가다
# 체중 : 64
# 신장 : 146
# BMI : 30
# 결과 : 비만
#
# 이름 : 아카
# 체중 : 58
# 신장 : 193
# BMI : 15
# 결과 : 저체중
#
# 이름 : 하라
# 체중 : 95
# 신장 : 158
# BMI : 38
# 결과 : 비만
#
# 이름 : 가마
# 체중 : 69
# 신장 : 167
# BMI : 24
# 결과 : 과체중
#
# 이름 : 바아
# 체중 : 57
# 신장 : 147
# BMI : 26
# 결과 : 비만
#
# 이름 : 차마
# 체중 : 68
# 신장 : 181
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 가가
# 체중 : 89
# 신장 : 198
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 파아
# 체중 : 86
# 신장 : 178
# BMI : 27
# 결과 : 비만
#
# 이름 : 아가
# 체중 : 73
# 신장 : 140
# BMI : 37
# 결과 : 비만
#
# 이름 : 파라
# 체중 : 87
# 신장 : 194
# BMI : 23
# 결과 : 과체중
#
# 이름 : 마바
# 체중 : 98
# 신장 : 165
# BMI : 35
# 결과 : 비만
#
# 이름 : 나파
# 체중 : 79
# 신장 : 176
# BMI : 25
# 결과 : 비만
#
# 이름 : 아카
# 체중 : 97
# 신장 : 154
# BMI : 40
# 결과 : 비만
#
# 이름 : 파라
# 체중 : 81
# 신장 : 198
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 아차
# 체중 : 72
# 신장 : 157
# BMI : 29
# 결과 : 비만
#
# 이름 : 다가
# 체중 : 85
# 신장 : 148
# BMI : 38
# 결과 : 비만
#
# 이름 : 다파
# 체중 : 50
# 신장 : 143
# BMI : 24
# 결과 : 과체중
#
# 이름 : 마바
# 체중 : 64
# 신장 : 196
# BMI : 16
# 결과 : 저체중
#
# 이름 : 아아
# 체중 : 63
# 신장 : 149
# BMI : 28
# 결과 : 비만
#
# 이름 : 아자
# 체중 : 98
# 신장 : 192
# BMI : 26
# 결과 : 비만
#
# 이름 : 타다
# 체중 : 43
# 신장 : 148
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 가파
# 체중 : 92
# 신장 : 175
# BMI : 30
# 결과 : 비만
#
# 이름 : 나바
# 체중 : 71
# 신장 : 145
# BMI : 33
# 결과 : 비만
#
# 이름 : 가마
# 체중 : 47
# 신장 : 193
# BMI : 12
# 결과 : 저체중
#
# 이름 : 가자
# 체중 : 99
# 신장 : 172
# BMI : 33
# 결과 : 비만
#
# 이름 : 차마
# 체중 : 89
# 신장 : 176
# BMI : 28
# 결과 : 비만
#
# 이름 : 하자
# 체중 : 43
# 신장 : 183
# BMI : 12
# 결과 : 저체중
#
# 이름 : 타마
# 체중 : 90
# 신장 : 182
# BMI : 27
# 결과 : 비만
#
# 이름 : 하카
# 체중 : 53
# 신장 : 161
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 가다
# 체중 : 56
# 신장 : 155
# BMI : 23
# 결과 : 과체중
#
# 이름 : 차사
# 체중 : 65
# 신장 : 161
# BMI : 25
# 결과 : 비만
#
# 이름 : 파차
# 체중 : 87
# 신장 : 174
# BMI : 28
# 결과 : 비만
#
# 이름 : 자타
# 체중 : 68
# 신장 : 144
# BMI : 32
# 결과 : 비만
#
# 이름 : 바사
# 체중 : 90
# 신장 : 163
# BMI : 33
# 결과 : 비만
#
# 이름 : 가마
# 체중 : 63
# 신장 : 191
# BMI : 17
# 결과 : 저체중
#
# 이름 : 마가
# 체중 : 71
# 신장 : 148
# BMI : 32
# 결과 : 비만
#
# 이름 : 가라
# 체중 : 46
# 신장 : 168
# BMI : 16
# 결과 : 저체중
#
# 이름 : 바타
# 체중 : 99
# 신장 : 189
# BMI : 27
# 결과 : 비만
#
# 이름 : 나차
# 체중 : 83
# 신장 : 159
# BMI : 32
# 결과 : 비만
#
# 이름 : 라아
# 체중 : 86
# 신장 : 168
# BMI : 30
# 결과 : 비만
#
# 이름 : 자바
# 체중 : 81
# 신장 : 179
# BMI : 25
# 결과 : 비만
#
# 이름 : 사사
# 체중 : 98
# 신장 : 169
# BMI : 34
# 결과 : 비만
#
# 이름 : 바파
# 체중 : 82
# 신장 : 180
# BMI : 25
# 결과 : 비만
#
# 이름 : 다카
# 체중 : 50
# 신장 : 190
# BMI : 13
# 결과 : 저체중
#
# 이름 : 바라
# 체중 : 94
# 신장 : 152
# BMI : 40
# 결과 : 비만
#
# 이름 : 바마
# 체중 : 93
# 신장 : 168
# BMI : 32
# 결과 : 비만
#
# 이름 : 나다
# 체중 : 43
# 신장 : 189
# BMI : 12
# 결과 : 저체중
#
# 이름 : 아마
# 체중 : 63
# 신장 : 161
# BMI : 24
# 결과 : 과체중
#
# 이름 : 하아
# 체중 : 60
# 신장 : 153
# BMI : 25
# 결과 : 비만
#
# 이름 : 나파
# 체중 : 93
# 신장 : 188
# BMI : 26
# 결과 : 비만
#
# 이름 : 아아
# 체중 : 40
# 신장 : 186
# BMI : 11
# 결과 : 저체중
#
# 이름 : 차라
# 체중 : 83
# 신장 : 167
# BMI : 29
# 결과 : 비만
#
# 이름 : 차사
# 체중 : 89
# 신장 : 197
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 마라
# 체중 : 80
# 신장 : 159
# BMI : 31
# 결과 : 비만
#
# 이름 : 차하
# 체중 : 98
# 신장 : 174
# BMI : 32
# 결과 : 비만
#
# 이름 : 파마
# 체중 : 74
# 신장 : 167
# BMI : 26
# 결과 : 비만
#
# 이름 : 라차
# 체중 : 47
# 신장 : 149
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 카바
# 체중 : 79
# 신장 : 170
# BMI : 27
# 결과 : 비만
#
# 이름 : 다차
# 체중 : 95
# 신장 : 161
# BMI : 36
# 결과 : 비만
#
# 이름 : 사가
# 체중 : 67
# 신장 : 197
# BMI : 17
# 결과 : 저체중
#
# 이름 : 마마
# 체중 : 71
# 신장 : 145
# BMI : 33
# 결과 : 비만
#
# 이름 : 가아
# 체중 : 50
# 신장 : 190
# BMI : 13
# 결과 : 저체중
#
# 이름 : 하차
# 체중 : 89
# 신장 : 146
# BMI : 41
# 결과 : 비만
#
# 이름 : 자사
# 체중 : 82
# 신장 : 155
# BMI : 34
# 결과 : 비만
#
# 이름 : 자사
# 체중 : 66
# 신장 : 154
# BMI : 27
# 결과 : 비만
#
# 이름 : 사라
# 체중 : 75
# 신장 : 194
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 하타
# 체중 : 98
# 신장 : 155
# BMI : 40
# 결과 : 비만
#
# 이름 : 자바
# 체중 : 45
# 신장 : 149
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 카바
# 체중 : 76
# 신장 : 143
# BMI : 37
# 결과 : 비만
#
# 이름 : 하바
# 체중 : 76
# 신장 : 180
# BMI : 23
# 결과 : 과체중
#
# 이름 : 자사
# 체중 : 75
# 신장 : 174
# BMI : 24
# 결과 : 과체중
#
# 이름 : 차사
# 체중 : 85
# 신장 : 165
# BMI : 31
# 결과 : 비만
#
# 이름 : 자자
# 체중 : 75
# 신장 : 156
# BMI : 30
# 결과 : 비만
#
# 이름 : 하카
# 체중 : 77
# 신장 : 154
# BMI : 32
# 결과 : 비만
#
# 이름 : 아다
# 체중 : 96
# 신장 : 162
# BMI : 36
# 결과 : 비만
#
# 이름 : 마아
# 체중 : 91
# 신장 : 176
# BMI : 29
# 결과 : 비만
#
# 이름 : 하마
# 체중 : 74
# 신장 : 156
# BMI : 30
# 결과 : 비만
#
# 이름 : 바자
# 체중 : 61
# 신장 : 159
# BMI : 24
# 결과 : 과체중
#
# 이름 : 가라
# 체중 : 65
# 신장 : 173
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 마하
# 체중 : 57
# 신장 : 190
# BMI : 15
# 결과 : 저체중
#
# 이름 : 마자
# 체중 : 92
# 신장 : 178
# BMI : 29
# 결과 : 비만
#
# 이름 : 다라
# 체중 : 84
# 신장 : 183
# BMI : 25
# 결과 : 비만
#
# 이름 : 가다
# 체중 : 78
# 신장 : 164
# BMI : 29
# 결과 : 비만
#
# 이름 : 카바
# 체중 : 74
# 신장 : 149
# BMI : 33
# 결과 : 비만
#
# 이름 : 가마
# 체중 : 76
# 신장 : 156
# BMI : 31
# 결과 : 비만
#
# 이름 : 파바
# 체중 : 66
# 신장 : 174
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 다다
# 체중 : 42
# 신장 : 172
# BMI : 14
# 결과 : 저체중
#
# 이름 : 자아
# 체중 : 91
# 신장 : 166
# BMI : 33
# 결과 : 비만
#
# 이름 : 나파
# 체중 : 46
# 신장 : 178
# BMI : 14
# 결과 : 저체중
#
# 이름 : 카라
# 체중 : 91
# 신장 : 159
# BMI : 35
# 결과 : 비만
#
# 이름 : 라가
# 체중 : 58
# 신장 : 165
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 타라
# 체중 : 59
# 신장 : 166
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 카차
# 체중 : 50
# 신장 : 199
# BMI : 12
# 결과 : 저체중
#
# 이름 : 사하
# 체중 : 72
# 신장 : 146
# BMI : 33
# 결과 : 비만
#
# 이름 : 카파
# 체중 : 50
# 신장 : 142
# BMI : 24
# 결과 : 과체중
#
# 이름 : 하타
# 체중 : 71
# 신장 : 176
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 나마
# 체중 : 98
# 신장 : 199
# BMI : 24
# 결과 : 과체중
#
# 이름 : 나다
# 체중 : 89
# 신장 : 145
# BMI : 42
# 결과 : 비만
#
# 이름 : 나바
# 체중 : 47
# 신장 : 179
# BMI : 14
# 결과 : 저체중
#
# 이름 : 나라
# 체중 : 49
# 신장 : 193
# BMI : 13
# 결과 : 저체중
#
# 이름 : 바마
# 체중 : 56
# 신장 : 188
# BMI : 15
# 결과 : 저체중
#
# 이름 : 사다
# 체중 : 43
# 신장 : 194
# BMI : 11
# 결과 : 저체중
#
# 이름 : 가가
# 체중 : 54
# 신장 : 198
# BMI : 13
# 결과 : 저체중
#
# 이름 : 차라
# 체중 : 52
# 신장 : 187
# BMI : 14
# 결과 : 저체중
#
# 이름 : 하나
# 체중 : 64
# 신장 : 180
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 나나
# 체중 : 66
# 신장 : 160
# BMI : 25
# 결과 : 비만
#
# 이름 : 사라
# 체중 : 93
# 신장 : 180
# BMI : 28
# 결과 : 비만
#
# 이름 : 바하
# 체중 : 40
# 신장 : 148
# BMI : 18
# 결과 : 저체중
#
# 이름 : 사아
# 체중 : 40
# 신장 : 166
# BMI : 14
# 결과 : 저체중
#
# 이름 : 마라
# 체중 : 43
# 신장 : 155
# BMI : 17
# 결과 : 저체중
#
# 이름 : 다마
# 체중 : 64
# 신장 : 156
# BMI : 26
# 결과 : 비만
#
# 이름 : 하마
# 체중 : 65
# 신장 : 176
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 바나
# 체중 : 75
# 신장 : 197
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 차카
# 체중 : 64
# 신장 : 199
# BMI : 16
# 결과 : 저체중
#
# 이름 : 카마
# 체중 : 81
# 신장 : 143
# BMI : 39
# 결과 : 비만
#
# 이름 : 파바
# 체중 : 83
# 신장 : 178
# BMI : 26
# 결과 : 비만
#
# 이름 : 마다
# 체중 : 48
# 신장 : 181
# BMI : 14
# 결과 : 저체중
#
# 이름 : 아하
# 체중 : 86
# 신장 : 155
# BMI : 35
# 결과 : 비만
#
# 이름 : 하하
# 체중 : 64
# 신장 : 191
# BMI : 17
# 결과 : 저체중
#
# 이름 : 자마
# 체중 : 49
# 신장 : 177
# BMI : 15
# 결과 : 저체중
#
# 이름 : 파파
# 체중 : 95
# 신장 : 195
# BMI : 24
# 결과 : 과체중
#
# 이름 : 타라
# 체중 : 79
# 신장 : 161
# BMI : 30
# 결과 : 비만
#
# 이름 : 사다
# 체중 : 66
# 신장 : 161
# BMI : 25
# 결과 : 비만
#
# 이름 : 카카
# 체중 : 74
# 신장 : 144
# BMI : 35
# 결과 : 비만
#
# 이름 : 카카
# 체중 : 78
# 신장 : 194
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 마타
# 체중 : 82
# 신장 : 160
# BMI : 32
# 결과 : 비만
#
# 이름 : 라카
# 체중 : 92
# 신장 : 195
# BMI : 24
# 결과 : 과체중
#
# 이름 : 카라
# 체중 : 97
# 신장 : 159
# BMI : 38
# 결과 : 비만
#
# 이름 : 아카
# 체중 : 48
# 신장 : 155
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 카사
# 체중 : 58
# 신장 : 168
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 나가
# 체중 : 82
# 신장 : 169
# BMI : 28
# 결과 : 비만
#
# 이름 : 가하
# 체중 : 87
# 신장 : 164
# BMI : 32
# 결과 : 비만
#
# 이름 : 마라
# 체중 : 93
# 신장 : 148
# BMI : 42
# 결과 : 비만
#
# 이름 : 하자
# 체중 : 98
# 신장 : 171
# BMI : 33
# 결과 : 비만
#
# 이름 : 사타
# 체중 : 99
# 신장 : 140
# BMI : 50
# 결과 : 비만
#
# 이름 : 나파
# 체중 : 50
# 신장 : 157
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 나가
# 체중 : 61
# 신장 : 188
# BMI : 17
# 결과 : 저체중
#
# 이름 : 다자
# 체중 : 66
# 신장 : 191
# BMI : 18
# 결과 : 저체중
#
# 이름 : 사차
# 체중 : 76
# 신장 : 188
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 다아
# 체중 : 61
# 신장 : 163
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 타바
# 체중 : 49
# 신장 : 196
# BMI : 12
# 결과 : 저체중
#
# 이름 : 나타
# 체중 : 88
# 신장 : 198
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 사하
# 체중 : 89
# 신장 : 155
# BMI : 37
# 결과 : 비만
#
# 이름 : 마파
# 체중 : 52
# 신장 : 148
# BMI : 23
# 결과 : 과체중
#
# 이름 : 파라
# 체중 : 66
# 신장 : 183
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 가파
# 체중 : 82
# 신장 : 161
# BMI : 31
# 결과 : 비만
#
# 이름 : 자파
# 체중 : 96
# 신장 : 169
# BMI : 33
# 결과 : 비만
#
# 이름 : 아타
# 체중 : 83
# 신장 : 168
# BMI : 29
# 결과 : 비만
#
# 이름 : 아사
# 체중 : 97
# 신장 : 191
# BMI : 26
# 결과 : 비만
#
# 이름 : 바가
# 체중 : 64
# 신장 : 178
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 차가
# 체중 : 62
# 신장 : 189
# BMI : 17
# 결과 : 저체중
#
# 이름 : 나마
# 체중 : 78
# 신장 : 189
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 아라
# 체중 : 64
# 신장 : 147
# BMI : 29
# 결과 : 비만
#
# 이름 : 마다
# 체중 : 82
# 신장 : 147
# BMI : 37
# 결과 : 비만
#
# 이름 : 자마
# 체중 : 77
# 신장 : 155
# BMI : 32
# 결과 : 비만
#
# 이름 : 하자
# 체중 : 85
# 신장 : 170
# BMI : 29
# 결과 : 비만
#
# 이름 : 마다
# 체중 : 91
# 신장 : 196
# BMI : 23
# 결과 : 과체중
#
# 이름 : 사아
# 체중 : 45
# 신장 : 145
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 다아
# 체중 : 88
# 신장 : 196
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 바사
# 체중 : 46
# 신장 : 167
# BMI : 16
# 결과 : 저체중
#
# 이름 : 다바
# 체중 : 65
# 신장 : 186
# BMI : 18
# 결과 : 저체중
#
# 이름 : 파라
# 체중 : 45
# 신장 : 175
# BMI : 14
# 결과 : 저체중
#
# 이름 : 바나
# 체중 : 68
# 신장 : 166
# BMI : 24
# 결과 : 과체중
#
# 이름 : 파나
# 체중 : 89
# 신장 : 190
# BMI : 24
# 결과 : 과체중
#
# 이름 : 하자
# 체중 : 98
# 신장 : 186
# BMI : 28
# 결과 : 비만
#
# 이름 : 바자
# 체중 : 63
# 신장 : 145
# BMI : 29
# 결과 : 비만
#
# 이름 : 마바
# 체중 : 96
# 신장 : 191
# BMI : 26
# 결과 : 비만
#
# 이름 : 차바
# 체중 : 74
# 신장 : 171
# BMI : 25
# 결과 : 비만
#
# 이름 : 라차
# 체중 : 65
# 신장 : 184
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 가자
# 체중 : 88
# 신장 : 183
# BMI : 26
# 결과 : 비만
#
# 이름 : 파카
# 체중 : 74
# 신장 : 176
# BMI : 23
# 결과 : 과체중
#
# 이름 : 바하
# 체중 : 73
# 신장 : 189
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 가바
# 체중 : 58
# 신장 : 163
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 파차
# 체중 : 67
# 신장 : 161
# BMI : 25
# 결과 : 비만
#
# 이름 : 다가
# 체중 : 48
# 신장 : 181
# BMI : 14
# 결과 : 저체중
#
# 이름 : 사나
# 체중 : 99
# 신장 : 157
# BMI : 40
# 결과 : 비만
#
# 이름 : 라타
# 체중 : 82
# 신장 : 169
# BMI : 28
# 결과 : 비만
#
# 이름 : 차나
# 체중 : 72
# 신장 : 186
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 가타
# 체중 : 68
# 신장 : 158
# BMI : 27
# 결과 : 비만
#
# 이름 : 타가
# 체중 : 43
# 신장 : 160
# BMI : 16
# 결과 : 저체중
#
# 이름 : 다차
# 체중 : 83
# 신장 : 148
# BMI : 37
# 결과 : 비만
#
# 이름 : 라다
# 체중 : 43
# 신장 : 181
# BMI : 13
# 결과 : 저체중
#
# 이름 : 파사
# 체중 : 76
# 신장 : 142
# BMI : 37
# 결과 : 비만
#
# 이름 : 마자
# 체중 : 56
# 신장 : 182
# BMI : 16
# 결과 : 저체중
#
# 이름 : 사바
# 체중 : 50
# 신장 : 161
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 마파
# 체중 : 67
# 신장 : 157
# BMI : 27
# 결과 : 비만
#
# 이름 : 하타
# 체중 : 53
# 신장 : 199
# BMI : 13
# 결과 : 저체중
#
# 이름 : 바사
# 체중 : 55
# 신장 : 159
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 하라
# 체중 : 91
# 신장 : 193
# BMI : 24
# 결과 : 과체중
#
# 이름 : 차나
# 체중 : 95
# 신장 : 197
# BMI : 24
# 결과 : 과체중
#
# 이름 : 차마
# 체중 : 98
# 신장 : 164
# BMI : 36
# 결과 : 비만
#
# 이름 : 라사
# 체중 : 74
# 신장 : 192
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 바다
# 체중 : 61
# 신장 : 194
# BMI : 16
# 결과 : 저체중
#
# 이름 : 바가
# 체중 : 85
# 신장 : 171
# BMI : 29
# 결과 : 비만
#
# 이름 : 가라
# 체중 : 52
# 신장 : 181
# BMI : 15
# 결과 : 저체중
#
# 이름 : 라하
# 체중 : 76
# 신장 : 163
# BMI : 28
# 결과 : 비만
#
# 이름 : 타다
# 체중 : 99
# 신장 : 174
# BMI : 32
# 결과 : 비만
#
# 이름 : 카차
# 체중 : 93
# 신장 : 161
# BMI : 35
# 결과 : 비만
#
# 이름 : 하자
# 체중 : 40
# 신장 : 170
# BMI : 13
# 결과 : 저체중
#
# 이름 : 바라
# 체중 : 85
# 신장 : 148
# BMI : 38
# 결과 : 비만
#
# 이름 : 카가
# 체중 : 76
# 신장 : 189
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 차차
# 체중 : 52
# 신장 : 193
# BMI : 13
# 결과 : 저체중
#
# 이름 : 카사
# 체중 : 79
# 신장 : 146
# BMI : 37
# 결과 : 비만
#
# 이름 : 나가
# 체중 : 58
# 신장 : 157
# BMI : 23
# 결과 : 과체중
#
# 이름 : 마아
# 체중 : 62
# 신장 : 161
# BMI : 23
# 결과 : 과체중
#
# 이름 : 카나
# 체중 : 68
# 신장 : 151
# BMI : 29
# 결과 : 비만
#
# 이름 : 타자
# 체중 : 96
# 신장 : 173
# BMI : 32
# 결과 : 비만
#
# 이름 : 하바
# 체중 : 84
# 신장 : 187
# BMI : 24
# 결과 : 과체중
#
# 이름 : 라아
# 체중 : 61
# 신장 : 170
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 자나
# 체중 : 91
# 신장 : 183
# BMI : 27
# 결과 : 비만
#
# 이름 : 라라
# 체중 : 73
# 신장 : 158
# BMI : 29
# 결과 : 비만
#
# 이름 : 마자
# 체중 : 91
# 신장 : 148
# BMI : 41
# 결과 : 비만
#
# 이름 : 아사
# 체중 : 47
# 신장 : 163
# BMI : 17
# 결과 : 저체중
#
# 이름 : 하나
# 체중 : 59
# 신장 : 159
# BMI : 23
# 결과 : 과체중
#
# 이름 : 마다
# 체중 : 73
# 신장 : 171
# BMI : 24
# 결과 : 과체중
#
# 이름 : 바하
# 체중 : 89
# 신장 : 140
# BMI : 45
# 결과 : 비만
#
# 이름 : 아나
# 체중 : 98
# 신장 : 198
# BMI : 24
# 결과 : 과체중
#
# 이름 : 나아
# 체중 : 83
# 신장 : 147
# BMI : 38
# 결과 : 비만
#
# 이름 : 하라
# 체중 : 77
# 신장 : 192
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 자파
# 체중 : 65
# 신장 : 175
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 파라
# 체중 : 51
# 신장 : 152
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 파카
# 체중 : 78
# 신장 : 170
# BMI : 26
# 결과 : 비만
#
# 이름 : 가나
# 체중 : 91
# 신장 : 151
# BMI : 39
# 결과 : 비만
#
# 이름 : 바마
# 체중 : 49
# 신장 : 146
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 타자
# 체중 : 66
# 신장 : 160
# BMI : 25
# 결과 : 비만
#
# 이름 : 나아
# 체중 : 82
# 신장 : 193
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 라하
# 체중 : 72
# 신장 : 169
# BMI : 25
# 결과 : 비만
#
# 이름 : 사바
# 체중 : 71
# 신장 : 177
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 자사
# 체중 : 98
# 신장 : 188
# BMI : 27
# 결과 : 비만
#
# 이름 : 마차
# 체중 : 46
# 신장 : 166
# BMI : 16
# 결과 : 저체중
#
# 이름 : 바파
# 체중 : 44
# 신장 : 168
# BMI : 15
# 결과 : 저체중
#
# 이름 : 가마
# 체중 : 85
# 신장 : 197
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 타마
# 체중 : 43
# 신장 : 157
# BMI : 17
# 결과 : 저체중
#
# 이름 : 파라
# 체중 : 64
# 신장 : 166
# BMI : 23
# 결과 : 과체중
#
# 이름 : 나아
# 체중 : 73
# 신장 : 176
# BMI : 23
# 결과 : 과체중
#
# 이름 : 가바
# 체중 : 42
# 신장 : 182
# BMI : 12
# 결과 : 저체중
#
# 이름 : 하파
# 체중 : 47
# 신장 : 160
# BMI : 18
# 결과 : 저체중
#
# 이름 : 나사
# 체중 : 44
# 신장 : 146
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 카가
# 체중 : 62
# 신장 : 166
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 차라
# 체중 : 75
# 신장 : 163
# BMI : 28
# 결과 : 비만
#
# 이름 : 아라
# 체중 : 41
# 신장 : 169
# BMI : 14
# 결과 : 저체중
#
# 이름 : 가타
# 체중 : 57
# 신장 : 165
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 마사
# 체중 : 74
# 신장 : 176
# BMI : 23
# 결과 : 과체중
#
# 이름 : 하바
# 체중 : 64
# 신장 : 172
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 하사
# 체중 : 84
# 신장 : 170
# BMI : 29
# 결과 : 비만
#
# 이름 : 나자
# 체중 : 68
# 신장 : 159
# BMI : 26
# 결과 : 비만
#
# 이름 : 나아
# 체중 : 59
# 신장 : 163
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 바사
# 체중 : 72
# 신장 : 168
# BMI : 25
# 결과 : 비만
#
# 이름 : 마나
# 체중 : 58
# 신장 : 193
# BMI : 15
# 결과 : 저체중
#
# 이름 : 다파
# 체중 : 75
# 신장 : 172
# BMI : 25
# 결과 : 비만
#
# 이름 : 차카
# 체중 : 99
# 신장 : 161
# BMI : 38
# 결과 : 비만
#
# 이름 : 나사
# 체중 : 54
# 신장 : 174
# BMI : 17
# 결과 : 저체중
#
# 이름 : 라아
# 체중 : 82
# 신장 : 155
# BMI : 34
# 결과 : 비만
#
# 이름 : 차다
# 체중 : 88
# 신장 : 166
# BMI : 31
# 결과 : 비만
#
# 이름 : 바자
# 체중 : 87
# 신장 : 169
# BMI : 30
# 결과 : 비만
#
# 이름 : 바차
# 체중 : 87
# 신장 : 183
# BMI : 25
# 결과 : 비만
#
# 이름 : 타나
# 체중 : 44
# 신장 : 150
# BMI : 19
# 결과 : 정상체중
#
# 이름 : 마마
# 체중 : 45
# 신장 : 157
# BMI : 18
# 결과 : 저체중
#
# 이름 : 사아
# 체중 : 52
# 신장 : 143
# BMI : 25
# 결과 : 비만
#
# 이름 : 차자
# 체중 : 79
# 신장 : 186
# BMI : 22
# 결과 : 정상체중
#
# 이름 : 하라
# 체중 : 70
# 신장 : 180
# BMI : 21
# 결과 : 정상체중
#
# 이름 : 차차
# 체중 : 62
# 신장 : 150
# BMI : 27
# 결과 : 비만
#
# 이름 : 차카
# 체중 : 52
# 신장 : 191
# BMI : 14
# 결과 : 저체중
#
# 이름 : 카바
# 체중 : 80
# 신장 : 199
# BMI : 20
# 결과 : 정상체중
#
# 이름 : 아하
# 체중 : 95
# 신장 : 190
# BMI : 26
# 결과 : 비만
#
# 이름 : 자아
# 체중 : 80
# 신장 : 182
# BMI : 24
# 결과 : 과체중
#
# 이름 : 아사
# 체중 : 89
# 신장 : 144
# BMI : 42
# 결과 : 비만
#
# 이름 : 차차
# 체중 : 88
# 신장 : 152
# BMI : 38
# 결과 : 비만
