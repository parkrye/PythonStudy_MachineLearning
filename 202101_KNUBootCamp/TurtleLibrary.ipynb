# %% [markdown]
# <a href="https://colab.research.google.com/github/parkrye/Python/blob/main/202101_KNUBootCamp/TurtleLibrary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #터틀 라이브러리 활용하기

# %% [markdown]
# ##터틀 라이브러리 임포팅

# %%
# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *

initializeTurtle()
# Out:
# ...
#   Created wheel for ColabTurtle: filename=ColabTurtle-2.1.0-py3-none-any.whl size=7657 sha256=d5662ce85a0a94fd7f7cccfadeeb0418963db44be9739ecffb6c83a46cec6e71
#   Stored in directory: /root/.cache/pip/wheels/0d/ab/65/cc4478508751448dfb4ecb20a6533082855c227dfce8c13902
# Successfully built ColabTurtle
# ...
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
import random

# !pip3 install ColabTurtle
from ColabTurtle.Turtle import *

initializeTurtle()

def color():
  r=random.randint(0,255)
  g=random.randint(0,255)
  b=random.randint(0,255)
  pencolor(r,g,b) 

shape('turtle')
pensize(1)

for i in range(5):
  forward(60)
  left(135)
  color()
# Out:
# ...
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:white;stroke-width:1"/><line x1="400.0" y1="150.0" x2="341.221" y2="230.902" stroke-linecap="round" style="stroke:rgb(192,164,29);stroke-width:1"/><line x1="341.221" y1="230.902" x2="436.327" y2="200.0" stroke-linecap="round" style="stroke:rgb(240,239,133);stroke-width:1"/><line x1="436.327" y1="200.0" x2="341.221" y2="169.098" stroke-linecap="round" style="stroke:rgb(210,220,183);stroke-width:1"/><line x1="341.221" y1="169.098" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:rgb(72,155,17);stroke-width:1"/>
#         <g visibility=visible transform="rotate(360,400.0,250.0) translate(382.0, 232.0)">
# ...
